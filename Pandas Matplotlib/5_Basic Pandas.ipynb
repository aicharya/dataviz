# %% [markdown]
# # Notebook-5 Pandas Basic - Auto Dataset

# %%
import pandas as pd

# %%
#https://archive.ics.uci.edu/ml/datasets/Auto+MPG

# %% [markdown]
# # Data Preparation

# %%
#Read the text file, its space separated
csv_path='auto-mpg.csv'
df = pd.read_csv(csv_path, header= None)
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.head()
# Out:
#                                                    0
# 0  18.0   8   307.0      130.0      3504.      12...
# 1  15.0   8   350.0      165.0      3693.      11...
# 2  18.0   8   318.0      150.0      3436.      11...
# 3  16.0   8   304.0      150.0      3433.      12...
# 4  17.0   8   302.0      140.0      3449.      10...

# %%
df.tail(3)
# Out:
#                                                      0
# 393  32.0   4   135.0      84.00      2295.      11...
# 394  28.0   4   120.0      79.00      2625.      18...
# 395  31.0   4   119.0      82.00      2720.      19...

# %%
#remove na values
df.dropna(inplace = True)

# %%
#Convert the space separated values file into columns using custom split logic 

first_part = df[0].str.split("   ", n = 9, expand = True)  #first split based on three white spaces
print(first_part.head())

remaining_part1 = first_part[9].str.split(" ", n = 1, expand = True) # second split on remaining items using single white space
#print(remaining_part1.head())

remaining_part2 = remaining_part1[1].str.split(" ", n = 1, expand = True) # third split on remaining items using  white space
#print(remaining_part2.head())

last_part = remaining_part2[1].str.split("1\t", n = 1, expand = True) # last plit on remaining items using tab
#print(last_part.head())
# Out:
#       0  1      2 3      4 5      6 7     8  \
# 0  18.0  8  307.0    130.0    3504.    12.0
# 1  15.0  8  350.0    165.0    3693.    11.5
# 2  18.0  8  318.0    150.0    3436.    11.0
# 3  16.0  8  304.0    150.0    3433.    12.0
# 4  17.0  8  302.0    140.0    3449.    10.5
#
#                                     9
# 0  70  1\t"chevrolet chevelle malibu"
# 1          70  1\t"buick skylark 320"
# 2         70  1\t"plymouth satellite"
# 3              70  1\t"amc rebel sst"
# 4                70  1\t"ford torino"

# %%
columns = ["mpg", "cylinders", "displacement", "horsepower", "weight", "acceleration", "model_year", "origin"]

# %%
#Frame the dataframe
auto_dataframe = pd.DataFrame()

auto_dataframe["mpg"] = first_part[0]
auto_dataframe["cylinders"] = first_part[1]
auto_dataframe["displacement"] = first_part[2]
auto_dataframe["horsepower"] = first_part[4]
auto_dataframe["weight"] = first_part[6]
auto_dataframe["weight"] = auto_dataframe["weight"].str.replace(".", "")
auto_dataframe["acceleration"] = first_part[8]
auto_dataframe["model_year"] = remaining_part1[0]
auto_dataframe["car_name"] = last_part[1]
auto_dataframe["car_name"] = auto_dataframe["car_name"].str.replace("\"", "")

auto_dataframe.head()
#print(auto_dataframe.head())
#df = auto_dataframe
# Out:
#     mpg cylinders displacement horsepower weight acceleration model_year  \
# 0  18.0         8        307.0      130.0   3504         12.0         70
# 1  15.0         8        350.0      165.0   3693         11.5         70
# 2  18.0         8        318.0      150.0   3436         11.0         70
# 3  16.0         8        304.0      150.0   3433         12.0         70
# 4  17.0         8        302.0      140.0   3449         10.5         70
#
#                     car_name
# 0  chevrolet chevelle malibu
# 1          buick skylark 320
# 2         plymouth satellite
# 3              amc rebel sst
# 4                ford torino

# %%
df = auto_dataframe

# %%
df.head(10)

# %%
df.tail()

# %%
df.tail(7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396 entries, 0 to 395
# Data columns (total 8 columns):
# mpg             396 non-null object
# cylinders       396 non-null object
# displacement    396 non-null object
# horsepower      396 non-null object
# weight          396 non-null object
# acceleration    396 non-null object
# model_year      396 non-null object
# car_name        247 non-null object
# dtypes: object(8)
# memory usage: 24.8+ KB

# %%
df["mpg"] = pd.to_numeric(df["mpg"])
df["cylinders"] = pd.to_numeric(df["cylinders"])
df["displacement"] = pd.to_numeric(df["displacement"])
df["weight"] = pd.to_numeric(df["weight"])
df["acceleration"] = pd.to_numeric(df["acceleration"])
df["displacement"] = pd.to_numeric(df["displacement"])
df["model_year"] = df["model_year"].astype(str)
df["car_name"] = df["car_name"].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396 entries, 0 to 395
# Data columns (total 8 columns):
# mpg             396 non-null float64
# cylinders       396 non-null int64
# displacement    396 non-null float64
# horsepower      396 non-null object
# weight          390 non-null float64
# acceleration    390 non-null float64
# model_year      396 non-null object
# car_name        396 non-null object
# dtypes: float64(4), int64(1), object(3)
# memory usage: 24.8+ KB

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration
# count  396.000000  396.000000    396.000000   390.000000    390.000000
# mean    23.562626    5.441919    192.142677  2970.451282     15.573590
# std      7.806295    1.695612    102.948816   845.683126      2.728191
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    103.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    146.000000  2797.500000     15.500000
# 75%     29.000000    8.000000    260.500000  3608.000000     17.075000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000

# %%
df.shape
# Out:
# (396, 8)

# %% [markdown]
# # Sorting

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration model_year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0         70
# 1  15.0          8         350.0      165.0  3693.0          11.5         70
# 2  18.0          8         318.0      150.0  3436.0          11.0         70
# 3  16.0          8         304.0      150.0  3433.0          12.0         70
# 4  17.0          8         302.0      140.0  3449.0          10.5         70
#
#                     car_name
# 0  chevrolet chevelle malibu
# 1          buick skylark 320
# 2         plymouth satellite
# 3              amc rebel sst
# 4                ford torino

# %%
# Sorting by values

# Sorting in increasing order of mpg
df.sort_values(by='mpg').head()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 26    9.0          8         304.0      193.0  4732.0          18.5
# 23   10.0          8         360.0      215.0  4615.0          14.0
# 24   10.0          8         307.0      200.0  4376.0          15.0
# 25   11.0          8         318.0      210.0  4382.0          13.5
# 101  11.0          8         400.0      150.0  4997.0          14.0
#
#     model_year          car_name
# 26          70          hi 1200d
# 23          70         ford f250
# 24          70         chevy c20
# 25          70        dodge d200
# 101         73  chevrolet impala

# %%
# Sorting in decresing order of mpg
df.sort_values(by='mpg', ascending = False).head()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 320  46.6          4          86.0      65.00  2110.0          17.9
# 327  44.6          4          91.0      67.00  1850.0          13.8
# 323  44.3          4          90.0      48.00  2085.0          21.7
# 392  44.0          4          97.0      52.00  2130.0          24.6
# 324  43.4          4          90.0      48.00  2335.0          23.7
#
#     model_year car_name
# 320         80     None
# 327         80     None
# 323         80     None
# 392         82     None
# 324         80     None

# %%
df.sort_values(by='mpg', ascending = False).head()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 320  46.6          4          86.0      65.00  2110.0          17.9
# 327  44.6          4          91.0      67.00  1850.0          13.8
# 323  44.3          4          90.0      48.00  2085.0          21.7
# 392  44.0          4          97.0      52.00  2130.0          24.6
# 324  43.4          4          90.0      48.00  2335.0          23.7
#
#     model_year car_name
# 320         80     None
# 327         80     None
# 323         80     None
# 392         82     None
# 324         80     None

# %%
# Sorting in decresing order of mpg, model_year
df.sort_values(by=['mpg', 'model_year'], ascending = False).head()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 320  46.6          4          86.0      65.00  2110.0          17.9
# 327  44.6          4          91.0      67.00  1850.0          13.8
# 323  44.3          4          90.0      48.00  2085.0          21.7
# 392  44.0          4          97.0      52.00  2130.0          24.6
# 324  43.4          4          90.0      48.00  2335.0          23.7
#
#     model_year car_name
# 320         80     None
# 327         80     None
# 323         80     None
# 392         82     None
# 324         80     None

# %% [markdown]
# # Accessing Features

# %%
mpg_df = df[['mpg']]
print(type(mpg_df))
print(mpg_df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     mpg
# 0  18.0
# 1  15.0
# 2  18.0
# 3  16.0
# 4  17.0

# %%
auto_details_df = df[['mpg', 'cylinders', "displacement"]]
print(type(auto_details_df))
print(auto_details_df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     mpg  cylinders  displacement
# 0  18.0          8         307.0
# 1  15.0          8         350.0
# 2  18.0          8         318.0
# 3  16.0          8         304.0
# 4  17.0          8         302.0

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration model_year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0         70
# 1  15.0          8         350.0      165.0  3693.0          11.5         70
# 2  18.0          8         318.0      150.0  3436.0          11.0         70
# 3  16.0          8         304.0      150.0  3433.0          12.0         70
# 4  17.0          8         302.0      140.0  3449.0          10.5         70
#
#                     car_name
# 0  chevrolet chevelle malibu
# 1          buick skylark 320
# 2         plymouth satellite
# 3              amc rebel sst
# 4                ford torino

# %%
#use **iloc** for integer indexes 
print("mpg " , df.iloc[0,0])
print("cylinders ", df.iloc[0,1])
print("displacement " , df.iloc[0,2])
# Out:
# mpg  18.0
# cylinders  8
# displacement  307.0

# %%
#use **loc** for label-location based indexer
print("mpg " , df.loc[0,'mpg'])
print("cylinders " , df.loc[0,'cylinders'])
print("displacement " , df.loc[0,'displacement'])
# Out:
# mpg  18.0
# cylinders  8
# displacement  307.0

# %%
df.iloc[0:2, 0:3]
# Out:
#     mpg  cylinders  displacement
# 0  18.0          8         307.0
# 1  15.0          8         350.0

# %%
df.loc[0:2, 'cylinders':'acceleration']
# Out:
#    cylinders  displacement horsepower  weight  acceleration
# 0          8         307.0      130.0  3504.0          12.0
# 1          8         350.0      165.0  3693.0          11.5
# 2          8         318.0      150.0  3436.0          11.0

# %%
df_cylinders = df.cylinders
df_cylinders.head()
# Out:
# 0    8
# 1    8
# 2    8
# 3    8
# 4    8
# Name: cylinders, dtype: int64

# %%
df[2:7]
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration model_year  \
# 2  18.0          8         318.0      150.0  3436.0          11.0         70
# 3  16.0          8         304.0      150.0  3433.0          12.0         70
# 4  17.0          8         302.0      140.0  3449.0          10.5         70
# 5  15.0          8         429.0      198.0  4341.0          10.0         70
# 6  14.0          8         454.0      220.0  4354.0           9.0         70
#
#              car_name
# 2  plymouth satellite
# 3       amc rebel sst
# 4         ford torino
# 5    ford galaxie 500
# 6    chevrolet impala

# %%
df[4::2].head()
# Out:
#      mpg  cylinders  displacement horsepower  weight  acceleration model_year  \
# 4   17.0          8         302.0      140.0  3449.0          10.5         70
# 6   14.0          8         454.0      220.0  4354.0           9.0         70
# 8   15.0          8         383.0      170.0  3563.0          10.0         70
# 10  15.0          8         400.0      150.0  3761.0           9.5         70
# 12  24.0          4         113.0      95.00  2372.0          15.0         70
#
#                  car_name
# 4             ford torino
# 6        chevrolet impala
# 8     dodge challenger se
# 10  chevrolet monte carlo
# 12                   None

# %%
print(type(df['cylinders']))
print(type(df_cylinders))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %% [markdown]
# # Filters

# %%
df.head()

# %%
# Select all rows where Runs > 15
df.mpg > 15
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4       True
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12      True
# 13      True
# 14      True
# 15      True
# 16      True
# 17      True
# 18      True
# 19      True
# 20      True
# 21      True
# 22      True
# 23     False
# 24     False
# 25     False
# 26     False
# 27      True
# 28      True
# 29      True
#        ...
# 366     True
# 367     True
# 368     True
# 369     True
# 370     True
# 371     True
# 372     True
# 373     True
# 374     True
# 375     True
# 376     True
# 377     True
# 378     True
# 379     True
# 380     True
# 381     True
# 382     True
# 383     True
# 384     True
# 385     True
# 386     True
# 387     True
# 388     True
# 389     True
# 390     True
# 391     True
# 392     True
# 393     True
# 394     True
# 395     True
# Name: mpg, Length: 396, dtype: bool

# %%
df.loc[df.mpg > 15, :]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0      130.0  3504.0          12.0
# 2    18.0          8         318.0      150.0  3436.0          11.0
# 3    16.0          8         304.0      150.0  3433.0          12.0
# 4    17.0          8         302.0      140.0  3449.0          10.5
# 12   24.0          4         113.0      95.00  2372.0          15.0
# 13   22.0          6         198.0      95.00  2833.0          15.5
# 14   18.0          6         199.0      97.00  2774.0          15.5
# 15   21.0          6         200.0      85.00  2587.0          16.0
# 16   27.0          4          97.0      88.00  2130.0          14.5
# 17   26.0          4          97.0      46.00  1835.0          20.5
# 18   25.0          4         110.0      87.00  2672.0          17.5
# 19   24.0          4         107.0      90.00  2430.0          14.5
# 20   25.0          4         104.0      95.00  2375.0          17.5
# ...

# %%
df.loc[ (df.mpg > 15)  & (df['cylinders'] == 4), :].head()
# Out:
#      mpg  cylinders  displacement horsepower  weight  acceleration model_year  \
# 12  24.0          4         113.0      95.00  2372.0          15.0         70
# 16  27.0          4          97.0      88.00  2130.0          14.5         70
# 17  26.0          4          97.0      46.00  1835.0          20.5         70
# 18  25.0          4         110.0      87.00  2672.0          17.5         70
# 19  24.0          4         107.0      90.00  2430.0          14.5         70
#
#    car_name
# 12     None
# 16     None
# 17     None
# 18     None
# 19     None

# %%
df.loc[ (df.mpg > 15)  | (df['cylinders'] == 4), :].head()
# Out:
#      mpg  cylinders  displacement horsepower  weight  acceleration model_year  \
# 0   18.0          8         307.0      130.0  3504.0          12.0         70
# 2   18.0          8         318.0      150.0  3436.0          11.0         70
# 3   16.0          8         304.0      150.0  3433.0          12.0         70
# 4   17.0          8         302.0      140.0  3449.0          10.5         70
# 12  24.0          4         113.0      95.00  2372.0          15.0         70
#
#                      car_name
# 0   chevrolet chevelle malibu
# 2          plymouth satellite
# 3               amc rebel sst
# 4                 ford torino
# 12                       None

# %%
df.loc[ (df.mpg > 15)  | (df['cylinders'] == 4), ['mpg', 'cylinders', 'displacement']].head()
# Out:
#      mpg  cylinders  displacement
# 0   18.0          8         307.0
# 2   18.0          8         318.0
# 3   16.0          8         304.0
# 4   17.0          8         302.0
# 12  24.0          4         113.0

# %%
years = ["70", "80"]
df.loc[df['model_year'].isin(years), :].head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration model_year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0         70
# 1  15.0          8         350.0      165.0  3693.0          11.5         70
# 2  18.0          8         318.0      150.0  3436.0          11.0         70
# 3  16.0          8         304.0      150.0  3433.0          12.0         70
# 4  17.0          8         302.0      140.0  3449.0          10.5         70
#
#                     car_name
# 0  chevrolet chevelle malibu
# 1          buick skylark 320
# 2         plymouth satellite
# 3              amc rebel sst
# 4                ford torino

# %% [markdown]
# # Grouping

# %%
df.head()

# %%
#form groups first
df_by_years = df.groupby('model_year')
df_by_years

# %%
df_by_years['mpg'].sum()
# Out:
# model_year
# 14.3     23.6
# 15.8     34.5
# 17.0     21.0
# 17.3     40.9
# 19.0     25.0
# 20.5     23.0
# 70      485.0
# 71      570.0
# 72      524.0
# 73      684.0
# 74      592.0
# 75      608.0
# 76      733.5
# 77      654.5
# 78      866.2
# 79      727.7
# 80      912.7
# 81      845.2
# 82      960.0
# Name: mpg, dtype: float64

# %%
df_by_years['mpg'].count()
# Out:
# model_year
# 14.3     1
# 15.8     1
# 17.0     1
# 17.3     1
# 19.0     1
# 20.5     1
# 70      27
# 71      27
# 72      28
# 73      40
# 74      26
# 75      30
# 76      34
# 77      28
# 78      36
# 79      29
# 80      27
# 81      28
# 82      30
# Name: mpg, dtype: int64

# %%
df_by_years.mpg.mean()
# Out:
# model_year
# 14.3    23.600000
# 15.8    34.500000
# 17.0    21.000000
# 17.3    40.900000
# 19.0    25.000000
# 20.5    23.000000
# 70      17.962963
# 71      21.111111
# 72      18.714286
# 73      17.100000
# 74      22.769231
# 75      20.266667
# 76      21.573529
# 77      23.375000
# 78      24.061111
# 79      25.093103
# 80      33.803704
# 81      30.185714
# 82      32.000000
# Name: mpg, dtype: float64

# %%
df_by_years.mpg.mean().sort_values(ascending = False)
# Out:
# model_year
# 17.3    40.900000
# 15.8    34.500000
# 80      33.803704
# 82      32.000000
# 81      30.185714
# 79      25.093103
# 19.0    25.000000
# 78      24.061111
# 14.3    23.600000
# 77      23.375000
# 20.5    23.000000
# 74      22.769231
# 76      21.573529
# 71      21.111111
# 17.0    21.000000
# 75      20.266667
# 72      18.714286
# 70      17.962963
# 73      17.100000
# Name: mpg, dtype: float64

# %%
# Converting to a df
pd.DataFrame(df_by_years['mpg'].mean())

# %%
by_year_cylinders = df.groupby(['model_year', 'cylinders'])
by_year_cylinders['mpg'].mean()
# Out:
# model_year  cylinders
# 14.3        4            23.600000
# 15.8        4            34.500000
# 17.0        6            21.000000
# 17.3        4            40.900000
# 19.0        4            25.000000
# 20.5        4            23.000000
# 70          4            25.285714
#             6            20.500000
#             8            14.125000
# 71          4            27.666667
#             6            18.000000
#             8            13.428571
# 72          3            19.000000
#             4            23.428571
#             8            13.615385
# 73          3            18.000000
#             4            22.727273
#             6            19.000000
#             8            13.200000
# 74          4            27.800000
#             6            17.333333
#             8            14.200000
# 75          4            25.250000
#             6            17.583333
#             8            15.666667
# 76          4            26.766667
# ...

# %%
by_year_cylinders['mpg'].describe()
# Out:
#                       count       mean       std   min     25%    50%     75%  \
# model_year cylinders
# 14.3       4            1.0  23.600000       NaN  23.6  23.600  23.60  23.600
# 15.8       4            1.0  34.500000       NaN  34.5  34.500  34.50  34.500
# 17.0       6            1.0  21.000000       NaN  21.0  21.000  21.00  21.000
# 17.3       4            1.0  40.900000       NaN  40.9  40.900  40.90  40.900
# 19.0       4            1.0  25.000000       NaN  25.0  25.000  25.00  25.000
# 20.5       4            1.0  23.000000       NaN  23.0  23.000  23.00  23.000
# 70         4            7.0  25.285714  1.112697  24.0  24.500  25.00  26.000
#            6            4.0  20.500000  1.732051  18.0  20.250  21.00  21.250
#            8           16.0  14.125000  2.777889   9.0  13.250  15.00  15.250
# 71         4           12.0  27.666667  3.576014  22.0  25.750  27.50  30.000
#            6            8.0  18.000000  1.069045  16.0  17.750  18.00  19.000
# ...

# %%
by_year_cylinders['mpg'].count()
# Out:
# model_year  cylinders
# 14.3        4             1
# 15.8        4             1
# 17.0        6             1
# 17.3        4             1
# 19.0        4             1
# 20.5        4             1
# 70          4             7
#             6             4
#             8            16
# 71          4            12
#             6             8
#             8             7
# 72          3             1
#             4            14
#             8            13
# 73          3             1
#             4            11
#             6             8
#             8            20
# 74          4            15
#             6             6
#             8             5
# 75          4            12
#             6            12
#             8             6
# 76          4            15
#             6            10
#             8             9
# 77          3             1
#             4            14
#             6             5
#             8             8
# ...

# %%
by_year_cylinders['mpg'].min()
# Out:
# model_year  cylinders
# 14.3        4            23.6
# 15.8        4            34.5
# 17.0        6            21.0
# 17.3        4            40.9
# 19.0        4            25.0
# 20.5        4            23.0
# 70          4            24.0
#             6            18.0
#             8             9.0
# 71          4            22.0
#             6            16.0
#             8            12.0
# 72          3            19.0
#             4            18.0
#             8            11.0
# 73          3            18.0
#             4            19.0
#             6            16.0
#             8            11.0
# 74          4            24.0
#             6            15.0
#             8            13.0
# 75          4            22.0
#             6            15.0
#             8            13.0
# 76          4            19.0
#             6            16.5
#             8            13.0
# 77          3            21.5
#             4            21.5
# ...

# %%
by_year_cylinders['mpg'].max()
